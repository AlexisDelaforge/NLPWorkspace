# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import NearestNeighbors

# %%
# nbrs = NearestNeighbors(n_neighbors=2, algorithm='ball_tree')

# %%
data = pd.read_csv('./very_all_points.csv')

# %%
data['nearest_neigbour'] = [None]*len(data)

# %%
data.head()
# Out:
#    Unnamed: 0     id         0         1         2         3         4  \
# 0           0  31239  0.253644 -0.321084 -0.589449 -0.970542  0.998823
# 1           0  49277 -0.569401 -0.987312 -0.599012 -0.194117  0.999915
# 2           0   1942 -0.099620 -0.986444 -0.361907  0.040220  0.960831
# 3           0  20118  0.808946 -0.716721 -0.590019 -0.362874  0.999995
# 4           0  60344 -0.784158 -0.942368 -0.527780 -0.306043 -0.835234
#
#           5         6         7  ...      1019      1020      1021      1022  \
# 0  0.319632  0.981234 -0.799514  ...  0.331789 -0.980479 -0.429701 -0.525760
# 1  0.700822 -0.892934  0.797688  ... -0.320049 -0.999913 -0.986968  0.289179
# 2  0.166444  0.993530  0.699363  ...  0.658584 -0.997743 -0.902522  0.806135
# 3  0.036835  0.978763  0.854471  ...  0.918464  0.038868 -0.910976 -0.989469
# 4  0.623065  0.975667 -0.918574  ... -0.568760 -0.832971 -0.108069  0.206828
#
#        1023  pred_class_0  pred_class_1  class  good_predict  frontier
# ...

# %%
data[data['id'] == 1381]
# Out:
#        Unnamed: 0    id         0         1         2         3         4  \
# 41205           0  1381  0.159272 -0.026184 -0.104087 -0.364945  0.999993
#
#               5         6         7  ...      1019      1020      1021  \
# 41205  0.265676 -0.172533 -0.540974  ...  0.349566  0.915985 -0.065645
#
#           1022      1023  pred_class_0  pred_class_1  class  good_predict  \
# 41205  0.55189 -0.759284  7.204785e-10           1.0      1          True
#
#        frontier
# 41205     False
#
# [1 rows x 1031 columns]

# %%
len(data[data['class'] == 1])
# Out:
# 13176

# %%
# data_cls_1 = data.loc[data['class'] == 1]
# data_cls_0 = data.loc[data['class'] == 0]
# data_tab = [data_cls_1, data_cls_0]

# %%
# for i in range(len(data)):
#     class_i = data['class'][i]
#     id_i = data['id'][i]
#     print(len(data_tab))
#     X = pd.concat([data[i], data_tab[class_i]]).iloc[:,2:1026].to_numpy()
#     # X = data_tab[class_i].append(data[i]).iloc[:,2:1026].to_numpy()
#     nbrs = nbrs.fit(X)
#     distances, indices = nbrs.kneighbors(X)
#     prov_data = data.loc[data['class'] != some_value]
#     X = data.iloc[:,2:1026].to_numpy()
#     data['nearest_neigbour'][i] = data['id'][neibourg_id]

# %%
# nbrs = nbrs.fit(X)

# %%
# distances, indices = nbrs.kneighbors(X)

# %%
from numpy import random
from scipy.spatial import distance

def closest_node(node, nodes):
    closest_index = distance.cdist([node], nodes).argmin()
    return closest_index, nodes[closest_index]

#a = random.randint(1000, size=(50000, 2))
for i in range(len(data)):
    class_i = data['class'][i]
    id_i = data['id'][i]
    a = data[data['class']!=class_i].iloc[lambda x: x.index != i, 2:1026].to_numpy()
    #some_pt = (1, 2)
    closest_index, closest_value = closest_node(data.iloc[i, 2:1026].to_numpy(), a)
    print(closest_index, closest_value)
    print(str(i)+"/"+str(len(data)))
    data['nearest_neigbour'][i] = data['id'][closest_index]
# Out:
# /home/alexis/.local/lib/python3.6/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()

# %%
data.iloc[0, 2:1026]
# Out:
# 0       0.253644
# 1      -0.321084
# 2      -0.589449
# 3      -0.970542
# 4       0.998823
#           ...
# 1019    0.331789
# 1020   -0.980479
# 1021   -0.429701
# 1022    -0.52576
# 1023   -0.922458
# Name: 0, Length: 1024, dtype: object

# %%
data.iloc[lambda x: x.index != 0,2:1026]
# Out:
#                0         1         2         3         4         5         6  \
# 1      -0.569401 -0.987312 -0.599012 -0.194117  0.999915  0.700822 -0.892934
# 2      -0.099620 -0.986444 -0.361907  0.040220  0.960831  0.166444  0.993530
# 3       0.808946 -0.716721 -0.590019 -0.362874  0.999995  0.036835  0.978763
# 4      -0.784158 -0.942368 -0.527780 -0.306043 -0.835234  0.623065  0.975667
# 5      -0.812745 -0.955966 -0.743353 -0.116108  0.985474  0.511381 -0.602548
# ...          ...       ...       ...       ...       ...       ...       ...
# 104359 -0.940447 -0.899166 -0.569543  0.123652  0.985020 -0.617012  0.645699
# 104360 -0.688172 -0.859654 -0.511220  0.020572  0.999849 -0.131492  0.997604
# 104361 -0.814291  0.782488 -0.735720 -0.144556  0.999998 -0.180351  0.020851
# 104362  0.236926 -0.442427 -0.966645  0.139687  0.999998 -0.368226 -0.881570
# 104363  0.491427 -0.866658 -0.661957  0.016605  0.988620  0.601567 -0.938614
#
# ...

# %%
data.to_csv('./with_neigbourghs.csv')
