# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./nn_frontier_V3_provisoire_10000.csv')
data = data.drop('Unnamed: 0', axis=1)

# %%
data[:12]
# Out:
#               id         0         1         2         3         4         5  \
# 0    31239_87918 -0.643436 -0.850516 -0.430191 -0.573974  0.999807  0.394134
# 1          31239  0.253644 -0.321084 -0.589449 -0.970542  0.998823  0.319632
# 2    49277_50417 -0.712807 -0.918899 -0.552527 -0.561892  0.999309  0.409713
# 3          49277 -0.569401 -0.987312 -0.599012 -0.194117  0.999915  0.700822
# 4     1942_19126 -0.730936 -0.921459 -0.147092 -0.221093  0.991928  0.619277
# 5           1942 -0.099620 -0.986444 -0.361907  0.040220  0.960831  0.166444
# 6   20118_104041  0.965786  0.743769 -0.300673 -0.781835  0.998372 -0.199299
# 7          20118  0.808946 -0.716721 -0.590019 -0.362874  0.999995  0.036835
# 8    60344_58133 -0.440421 -0.942364 -0.015288 -0.165652  0.538298 -0.201445
# 9          60344 -0.784158 -0.942368 -0.527780 -0.306043 -0.835234  0.623065
# 10   57662_14443 -0.283816 -0.835727 -0.838947 -0.313331  0.998736 -0.228584
# ...

# %%
# data = data[data['class'] == 'frontier']

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
data['class'].value_counts()
# Out:
# frontier    9848
# 0           8786
# 1           1214
# Name: class, dtype: int64

# %%
sns.distplot(data['value_0'], kde=False, rug=False);

# %%
sns.distplot(data['value_1'], kde=False, rug=False);

# %%
sns.distplot(data['value_0']-data['value_1'], kde=False, rug=False) #, title='value_1-value_0');

# %%
# data[10000:10020]

# %%
# data[data['id']==70876]['nearest']

# %%
# data['class'] = [1 if value != 'frontier' and value !='0' else value for value in data['class']]

# %%
# data.head()

# %%
# data[data['class']=='frontier']

# %%
len(data)
# Out:
# 19848

# %%
# data_start_points[100:120]

# %%
# sum(data_start_points['good_predict'])

# %%
# (len(data)-len(data[data['class']=='frontier']))/2

# %%
# len(data_start_points)

# %%
# data[data['class']==1]

# %%
# data_start_points[data_start_points['id']==99595]

# %%
# sum(data_start_points[data_start_points['class']==1]['good_predict'])

# %%
# len(data_start_points[data_start_points['class']==1])

# %%
# sum(data_start_points[data_start_points['class']==0]['good_predict'])

# %%
# len(data_start_points[data_start_points['class']==0])

# %%
# len(data[data['class']=='frontier'])

# %%
# sum(data[data['class']=='0']['good_predict'])

# %%
# len(data[data['class']=='0'])

# %%
# sum(data[data['class']==1]['good_predict'])

# %%
# len(data[data['class']==1])µ

# %%
# data['id'].value_counts()

# %%
# data[data['id']==49277].head()

# %%
data.head()
# Out:
#             id         0         1         2         3         4         5  \
# 0  31239_87918 -0.643436 -0.850516 -0.430191 -0.573974  0.999807  0.394134
# 1        31239  0.253644 -0.321084 -0.589449 -0.970542  0.998823  0.319632
# 2  49277_50417 -0.712807 -0.918899 -0.552527 -0.561892  0.999309  0.409713
# 3        49277 -0.569401 -0.987312 -0.599012 -0.194117  0.999915  0.700822
# 4   1942_19126 -0.730936 -0.921459 -0.147092 -0.221093  0.991928  0.619277
#
#           6         7         8  ...      1022      1023  pred_class_0  \
# 0  0.831877  0.506907 -0.216235  ... -0.587946 -0.574902      0.495721
# 1  0.981234 -0.799514 -0.240576  ... -0.525760 -0.922458      1.000000
# 2 -0.743229  0.854451 -0.015443  ... -0.560251 -0.478924      0.506250
# 3 -0.892934  0.797688  0.506043  ...  0.289179 -0.564293      1.000000
# 4  0.963386  0.098669 -0.202306  ...  0.881488 -0.656407      0.494795
#
#    pred_class_1     class  good_predict  frontier  nearest    value_0  \
# ...

# %%
# data_start_points[data_start_points['id']==21447]

# %%
# data[0:15]

# %%
# for index, row in data.iterrows():
#     if row['class'] == 'frontier':
#         data_start_points.append(row)

# data_start_points.to_csv('./with_neigbourghs_and_frontier_V1.csv')

# %%
# data_start_points = data_start_points.append(data[data['class']=='frontier'])

# %%
# len(data_start_points)

# %%
# data_start_points.to_csv('./with_neigbourghs_and_frontier_V2.csv')

# %%
base_data = pd.read_csv('./nn_frontier_V3_provisoire_10000.csv')

# %%
base_data.index = base_data['id']
# data = pd.read_csv('./with_neigbourghs_and_frontier_V1.csv')
# iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
# iris_df['species'] = pd.Series(iris.target).map(dict(zip(range(3),iris.target_names)))
# sns.pairplot(iris_df, hue='species');
data_target = base_data['class']
# data_target = [x if x != 'frontier' else 3 for x in data_target]
data_target = [int(x) if x == "0" or x == "1" else 3 for x in data_target]


# iris_df['species'] = pd.Series(iris.target).map(dict(zip(range(3),iris.target_names)))
# sns.pairplot(data, hue='class')

# %%
base_data.head()
# Out:
#              Unnamed: 0           id         0         1         2         3  \
# id
# 31239_87918           0  31239_87918 -0.643436 -0.850516 -0.430191 -0.573974
# 31239                 0        31239  0.253644 -0.321084 -0.589449 -0.970542
# 49277_50417           0  49277_50417 -0.712807 -0.918899 -0.552527 -0.561892
# 49277                 0        49277 -0.569401 -0.987312 -0.599012 -0.194117
# 1942_19126            0   1942_19126 -0.730936 -0.921459 -0.147092 -0.221093
#
#                     4         5         6         7  ...      1022      1023  \
# id                                                   ...
# 31239_87918  0.999807  0.394134  0.831877  0.506907  ... -0.587946 -0.574902
# 31239        0.998823  0.319632  0.981234 -0.799514  ... -0.525760 -0.922458
# 49277_50417  0.999309  0.409713 -0.743229  0.854451  ... -0.560251 -0.478924
# 49277        0.999915  0.700822 -0.892934  0.797688  ...  0.289179 -0.564293
# ...

# %%
data = base_data.drop(['Unnamed: 0','id', 'pred_class_0', 'pred_class_1', 'class','good_predict','frontier','nearest','value_0','value_1'],1)

# %%
data.head()
# Out:
#                     0         1         2         3         4         5  \
# id
# 31239_87918 -0.643436 -0.850516 -0.430191 -0.573974  0.999807  0.394134
# 31239        0.253644 -0.321084 -0.589449 -0.970542  0.998823  0.319632
# 49277_50417 -0.712807 -0.918899 -0.552527 -0.561892  0.999309  0.409713
# 49277       -0.569401 -0.987312 -0.599012 -0.194117  0.999915  0.700822
# 1942_19126  -0.730936 -0.921459 -0.147092 -0.221093  0.991928  0.619277
#
#                     6         7         8    9  ...      1014      1015  \
# id                                              ...
# 31239_87918  0.831877  0.506907 -0.216235  1.0  ...  0.479929 -0.179241
# 31239        0.981234 -0.799514 -0.240576  1.0  ...  0.888300 -0.267791
# 49277_50417 -0.743229  0.854451 -0.015443  1.0  ...  0.412249 -0.010704
# 49277       -0.892934  0.797688  0.506043  1.0  ... -0.097767 -0.041873
# 1942_19126   0.963386  0.098669 -0.202306  1.0  ...  0.120347 -0.094877
#
# ...

# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


import numpy as np
import pandas as pd

# base_data = pd.read_csv('../NLPWorkspace/executions/FRONTIER/with_neigbourghs_and_frontier_V2.csv')
base_data = pd.read_csv('./nn_frontier_V3_provisoire_10000.csv')
base_data.index = base_data['id']
# data = pd.read_csv('./with_neigbourghs_and_frontier_V1.csv')
# iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
# iris_df['species'] = pd.Series(iris.target).map(dict(zip(range(3),iris.target_names)))
# sns.pairplot(iris_df, hue='species');
data_target = base_data['class']
# data_target = [x if x != 'frontier' else 3 for x in data_target]
data_target = [int(x) if x == "0" or x == "1" else 3 for x in data_target]


# iris_df['species'] = pd.Series(iris.target).map(dict(zip(range(3),iris.target_names)))
# sns.pairplot(data, hue='class')


# In[6]:


import umap


# In[7]:


reducer = umap.UMAP()


# In[9]:


data = base_data.drop(['Unnamed: 0','id', 'pred_class_0', 'pred_class_1', 'class','good_predict','frontier','nearest','value_0','value_1'],1)

result, sigmas, rhos = umap.umap_.fuzzy_simplicial_set(data.to_numpy(np.float32), 5, np.random.RandomState(42), 'euclidean')



def tulip_creator(matrix, data, base_data, name):
    with open(str(name)+'.tlp', 'a') as the_file:
        the_file.write('(tlp "2.3"\n')
        the_file.write('(nb_nodes '+str(data.to_numpy().shape[0]) +')\n')
        edges = ''
        nodes = '(nodes '
        weigth = '(property 0 double "viewMetric"\n'
        weigth+= '\t(default "0" "0" )\n'
        label = '(property  0 string "viewLabel"\n'
        label += '\t(default "" "")\n'
        class_col = '(property  0 color "viewColor"\n'
        class_col += '\t(default "(235,0,23,255)" "(0,0,0,120)")\n'
        egdes_id = 0
        for i in range(data.to_numpy().shape[0]):
            for nn in matrix[i]:
                value_indice = 0
                nodes += str(i)+" "
                label += '(node '+str(i)+' "'+str(data.iloc[i].name)+'")\n'
                if base_data.loc[data.iloc[i].name]['class']=='frontier':
                    class_col += '(node '+str(i)+' "(200,0,0,255)")\n'
                elif int(base_data.loc[data.iloc[i].name]['class'])==1:
                    class_col += '(node '+str(i)+' "(0,200,0,255)")\n'
                else:
                    class_col += '(node '+str(i)+' "(0,0,200,255)")\n'
                for k in nn.indices:
                    value = nn.data[value_indice]
                    value_indice += 1
                    if i < k:
                        egdes_id += 1
                        edges += '(edge '+str(egdes_id)+' '+str(i)+' '+str(k)+')\n'
                        weigth += '\t(edge '+str(egdes_id)+' "'+str(value)+'" )\n'
        the_file.write(nodes+')\n')
        the_file.write('(nb_edges '+str(egdes_id)+')\n')
        the_file.write(edges)
        the_file.write(weigth+'\t)\n')
        the_file.write(label+'\t)\n')
        the_file.write(class_col+'\t)\n')
        the_file.write(')')


# In[22]:


tulip_creator(result, data, base_data, 'graph_V2')
# Out:
# /usr/local/lib/python3.6/dist-packages/numba/core/errors.py:144: UserWarning: Insufficiently recent colorama version found. Numba requires colorama >= 0.3.9
#   warnings.warn(msg)
# /usr/local/lib/python3.6/dist-packages/umap/spectral.py:4: NumbaDeprecationWarning: No direct replacement for 'numba.targets' available. Visit https://gitter.im/numba/numba-dev to request help. Thanks!
#   import numba.targets

# %%
import pickle as pkl

# %%
# embedding = reducer.fit_transform(data[['pred_class_0', 'pred_class_1']][:])

fit = umap.UMAP(n_components=1)

frontier_data = base_data[base_data['class']=='frontier'].drop(['Unnamed: 0','id', 'pred_class_0', 'pred_class_1', 'class','good_predict','frontier','nearest','value_0','value_1'],1)
class_data = base_data[base_data['class']!='frontier'].drop(['Unnamed: 0','id', 'pred_class_0', 'pred_class_1', 'class','good_predict','frontier','nearest','value_0','value_1'],1)

u = fit.fit_transform(frontier_data)

v = fit.transform(class_data)

# embedding = reducer.fit_transform(data)
# embedding.shape

# mapper = umap.UMAP().fit(data)

pkl.dump(u, open('embedding_V1.umap', 'wb'))
pkl.dump(u, open('mapper_V1.umap', 'wb'))


# In[ ]:


# data[['pred_class_0', 'pred_class_1']].head()




# In[ ]:


plt.scatter(
    v[:, 0],
    v[:, 0],
    s=0.25,
    c=[sns.color_palette()[x] for x in list(map(int,base_data[base_data['class']!='frontier']['class']))]
)
plt.gca().set_aspect('equal', 'datalim')
plt.title('UMAP projection of the 37461 sentences', fontsize=24);
plt.savefig('./nn_frontier_V1.png')
plt.savefig('./nn_frontier_V1.png')
# Out:
# /usr/lib/python3.6/importlib/__init__.py:126: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import requested from: 'numba.targets.registry', please update to use 'numba.core.registry' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   return _bootstrap._gcd_import(name[level:], package, level)
# /usr/local/lib/python3.6/dist-packages/umap/spectral.py:106: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'CPUDispatcher' requested from: 'numba.targets.registry', please update to use 'numba.core.registry' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   ) == numba.targets.registry.CPUDispatcher and scipy.sparse.isspmatrix(data):

# %%
base_data = pd.read_csv('./nn_frontier_V3_provisoire_10000.csv')
base_data = base_data.drop('Unnamed: 0', axis=1)

# %%
frontier_data = base_data[base_data['class']=='frontier']
class_data = base_data[base_data['class']!='frontier']

# %%
class_data['UMAP_D1_value'] = v[:, 0]
frontier_data['UMAP_D1_value'] = u[:, 0]
# Out:
# /home/alexis/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/alexis/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
class_data.head()
# Out:
#       id         0         1         2         3         4         5  \
# 1  31239  0.253644 -0.321084 -0.589449 -0.970542  0.998823  0.319632
# 3  49277 -0.569401 -0.987312 -0.599012 -0.194117  0.999915  0.700822
# 5   1942 -0.099620 -0.986444 -0.361907  0.040220  0.960831  0.166444
# 7  20118  0.808946 -0.716721 -0.590019 -0.362874  0.999995  0.036835
# 9  60344 -0.784158 -0.942368 -0.527780 -0.306043 -0.835234  0.623065
#
#           6         7         8  ...      1023  pred_class_0  pred_class_1  \
# 1  0.981234 -0.799514 -0.240576  ... -0.922458  1.000000e+00  1.740372e-25
# 3 -0.892934  0.797688  0.506043  ... -0.564293  1.000000e+00  8.848381e-27
# 5  0.993530  0.699363 -0.028185  ... -0.645377  1.000000e+00  2.634413e-26
# 7  0.978763  0.854471 -0.250788  ... -0.224594  1.077525e-11  1.000000e+00
# 9  0.975667 -0.918574  0.009565  ... -0.823972  1.000000e+00  4.594579e-27
#
#    class  good_predict  frontier   nearest    value_0    value_1  \
# ...

# %%
base_data = class_data.append(frontier_data)

# %%
base_data.head()
# Out:
#       id         0         1         2         3         4         5  \
# 1  31239  0.253644 -0.321084 -0.589449 -0.970542  0.998823  0.319632
# 3  49277 -0.569401 -0.987312 -0.599012 -0.194117  0.999915  0.700822
# 5   1942 -0.099620 -0.986444 -0.361907  0.040220  0.960831  0.166444
# 7  20118  0.808946 -0.716721 -0.590019 -0.362874  0.999995  0.036835
# 9  60344 -0.784158 -0.942368 -0.527780 -0.306043 -0.835234  0.623065
#
#           6         7         8  ...      1023  pred_class_0  pred_class_1  \
# 1  0.981234 -0.799514 -0.240576  ... -0.922458  1.000000e+00  1.740372e-25
# 3 -0.892934  0.797688  0.506043  ... -0.564293  1.000000e+00  8.848381e-27
# 5  0.993530  0.699363 -0.028185  ... -0.645377  1.000000e+00  2.634413e-26
# 7  0.978763  0.854471 -0.250788  ... -0.224594  1.077525e-11  1.000000e+00
# 9  0.975667 -0.918574  0.009565  ... -0.823972  1.000000e+00  4.594579e-27
#
#    class  good_predict  frontier   nearest    value_0    value_1  \
# ...

# %%
base_data.to_csv('./nn_frontier_UMAP_V3_provisoire_10000.csv')

# %%
plt.figure(figsize=(20,10))
plt.scatter(
    base_data[base_data['class']!='frontier']['value_0']-base_data[base_data['class']!='frontier']['value_1'],
    base_data[base_data['class']!='frontier']['UMAP_D1_value'],
    s=1,
    c=[sns.color_palette()[x] for x in list(map(int,base_data[base_data['class']!='frontier']['class']))]
)
plt.gca().set_aspect('equal', 'datalim')
plt.axvline(x=0.0, color=sns.color_palette()[3])
plt.title('UMAP projection of the 100000 sentences', fontsize=24);

# %%
import pickle as pkl

# %%
with open(r"last_FC.pkl", "rb") as input_file:
    plans = pkl.load(input_file)

# %%
plans.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.099718 -0.077390 -0.305392  0.256532 -0.033397  0.220542  0.105602
# 0  0.027849  0.017681  0.133197 -0.098239  0.030657 -0.089705  0.001464
#
#           7         8         9  ...      1015      1016      1017      1018  \
# 0 -0.051412 -0.292714  0.012570  ...  0.048517 -0.018064 -0.039292  0.071533
# 0  0.136552  0.187572 -0.009032  ... -0.008740  0.002646  0.013864 -0.100081
#
#        1019      1020      1021      1022      1023     biais
# 0 -0.090711 -0.501262  0.014179  0.174267 -0.059700  0.007720
# 0  0.069355  0.321744 -0.021818 -0.032914  0.105219 -0.028876
#
# [2 rows x 1025 columns]

# %%
plans = plans.reset_index().drop('index', axis=1)

# %%
plans
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.099718 -0.077390 -0.305392  0.256532 -0.033397  0.220542  0.105602
# 1  0.027849  0.017681  0.133197 -0.098239  0.030657 -0.089705  0.001464
#
#           7         8         9  ...      1015      1016      1017      1018  \
# 0 -0.051412 -0.292714  0.012570  ...  0.048517 -0.018064 -0.039292  0.071533
# 1  0.136552  0.187572 -0.009032  ... -0.008740  0.002646  0.013864 -0.100081
#
#        1019      1020      1021      1022      1023     biais
# 0 -0.090711 -0.501262  0.014179  0.174267 -0.059700  0.007720
# 1  0.069355  0.321744 -0.021818 -0.032914  0.105219 -0.028876
#
# [2 rows x 1025 columns]

# %%
plans = plans.append(pd.DataFrame([plans.loc[0,:] - plans.loc[1,:]]))

# %%
plans.index = ['fc0','fc1','fc0-fc1']

# %%
plans.head()
# Out:
#                 0         1         2         3         4         5         6  \
# fc0     -0.099718 -0.077390 -0.305392  0.256532 -0.033397  0.220542  0.105602
# fc1      0.027849  0.017681  0.133197 -0.098239  0.030657 -0.089705  0.001464
# fc0-fc1 -0.127567 -0.095071 -0.438589  0.354771 -0.064054  0.310246  0.104137
#
#                 7         8         9  ...      1015      1016      1017  \
# fc0     -0.051412 -0.292714  0.012570  ...  0.048517 -0.018064 -0.039292
# fc1      0.136552  0.187572 -0.009032  ... -0.008740  0.002646  0.013864
# fc0-fc1 -0.187964 -0.480286  0.021602  ...  0.057257 -0.020710 -0.053156
#
#              1018      1019      1020      1021      1022      1023     biais
# fc0      0.071533 -0.090711 -0.501262  0.014179  0.174267 -0.059700  0.007720
# fc1     -0.100081  0.069355  0.321744 -0.021818 -0.032914  0.105219 -0.028876
# fc0-fc1  0.171614 -0.160066 -0.823006  0.035997  0.207181 -0.164918  0.036595
#
# [3 rows x 1025 columns]

# %%
one_point = base_data.iloc[10,1:1025].append(pd.DataFrame([0])).transpose()

# %%
one_point.columns = plans.columns

# %%
plans = plans.append(one_point)

# %%
plans.index = ['fc0','fc1','fc0-fc1','one_point']

# %%
plans.head()
# Out:
#                    0          1         2          3          4          5  \
# fc0       -0.0997175 -0.0773904 -0.305392   0.256532 -0.0333974   0.220542
# fc1        0.0278491  0.0176806  0.133197 -0.0982391  0.0306566 -0.0897046
# fc0-fc1    -0.127567 -0.0950711 -0.438589   0.354771  -0.064054   0.310246
# one_point  -0.891055   0.998017 -0.147218    -0.2871  0.0317093  -0.885108
#
#                     6          7         8           9  ...        1015  \
# fc0          0.105602 -0.0514118 -0.292714   0.0125698  ...   0.0485169
# fc1        0.00146428   0.136552  0.187572 -0.00903186  ... -0.00874019
# fc0-fc1      0.104137  -0.187964 -0.480286   0.0216016  ...   0.0572571
# one_point    0.774834   0.189663  0.190572           1  ...   -0.340952
#
#                  1016       1017       1018       1019      1020       1021  \
# fc0        -0.0180637 -0.0392919  0.0715327 -0.0907111 -0.501262  0.0141791
# ...

# %%
x = plans.loc['one_point']
x['biais'] = 1
x
# Out:
# 0        -0.891055
# 1         0.998017
# 2        -0.147218
# 3          -0.2871
# 4        0.0317093
#            ...
# 1020     -0.399777
# 1021     -0.913176
# 1022     -0.991191
# 1023     -0.959183
# biais            1
# Name: one_point, Length: 1025, dtype: object

# %%
# (np.absolute(np.dot(p[0:1024],x[0:1024]) + p['biais'])/np.linalg.norm(p[0:1024]))

# %%
# (np.absolute(np.dot(p[0:1024]/np.linalg.norm(p[0:1024]),x[0:1024]) + p['biais']/np.linalg.norm(p[0:1024])))

# %%
# (np.absolute(np.dot(p[0:1024]/np.linalg.norm(p[0:1024]),x[0:1024]) + p['biais']))

# %%
# plans.loc['fc0-fc1']/np.linalg.norm(p[0:1024])

# %%
# x-<p,x>p

x = plans.loc['one_point']
p = plans.loc['fc0-fc1']

# np.dot( p[0:1024], x[0:1024] ) + p['biais']

#new_point = x - ( np.absolute(np.dot(p[0:1024],x[0:1024]) ) ) * p[0:1024] + p['biais']**2
# new_point = x[0:1024] - (np.absolute(np.dot(p[0:1024], x[0:1024]) + p['biais']))/np.linalg.norm(p[0:1024])**2 * p[0:1024]
# new_point = x[0:1024] - (np.dot( p, x )/np.linalg.norm(p[0:1024])) * p[0:1024]
new_point = x[0:1024] - np.dot( p, x )/(np.linalg.norm(p[0:1024]))**2 * p[0:1024]

# %%
new_point
# new_point = new_point[0:1024].append(pd.Series([1]))
# Out:
# 0       -0.839166
# 1         1.03669
# 2       0.0311821
# 3       -0.431406
# 4       0.0577638
#           ...
# 1019    -0.361518
# 1020   -0.0650112
# 1021    -0.927818
# 1022     -1.07546
# 1023    -0.892101
# Length: 1024, dtype: object

# %%
np.dot(new_point, p[0:1024]) # + p['biais']
#np.dot(new_point, p, out=None)
# Out:
# -0.03659514896561211

# %%
p['biais']
# Out:
# 0.03659514896571636

# %%
# x-<p,x>p

# x = plans.loc['one_point']
# x['biais'] = 1
# p = plans.loc['fc0-fc1']

# new_point = x - (np.dot(p, x)- p['biais'])/np.linalg.norm(p) * p

# %%
new_point

# %%
new_point

# %%
class_data.head()

# %%
point_frontière_projection = pd.DataFrame(columns=list(range(1024)))

# %%
for i in range(len(class_data)):
    if i%1000 == 0:
        print(str(i)+"/"+str(len(class_data)))
    one_point = base_data.iloc[i,1:1025].append(pd.DataFrame([1])).transpose()
    x = one_point.iloc[0].reset_index(drop=True)
#     print(type(x))
#     print(x)
    p = plans.loc['fc0-fc1'].reset_index(drop=True)
#     print(type(p))
#     print(p[0:1024])
    new_point = x[0:1024] - (np.dot( p, x )/(np.linalg.norm(p[0:1024]))**2)* p[0:1024]
#     print(new_point)
    point_frontière_projection = point_frontière_projection.append(new_point, ignore_index=True, )
    point_frontière_projection.head()
#     print(new_point.append(pd.DataFrame([0])))
#     class_data = class_data.append(new_point)
# Out:
# 0/10000
# 1000/10000
# 2000/10000
# 3000/10000
# 4000/10000
# 5000/10000
# 6000/10000
# 7000/10000
# 8000/10000
# 9000/10000

# %%
x - np.dot(p, x)

# %%
x.reset_index(drop=True) - np.dot(p, x) * p.reset_index(drop=True)
